# %%
# !pip install pytrends
# Out:
# Collecting pytrends
#   Downloading pytrends-4.9.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: lxml in /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages (from pytrends) (4.9.1)
# Requirement already satisfied: requests>=2.0 in /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages (from pytrends) (2.28.1)
# Requirement already satisfied: pandas>=0.25 in /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages (from pytrends) (1.5.3)
# Requirement already satisfied: numpy>=1.20.3 in /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25->pytrends) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25->pytrends) (2022.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0->pytrends) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0->pytrends) (2024.2.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0->pytrends) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0->pytrends) (2.0.4)
# Requirement already satisfied: six>=1.5 in /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.25->pytrends) (1.16.0)
# Installing collected packages: pytrends
# Successfully installed pytrends-4.9.2

# %%
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt
#gtrend.py in separate file
from gtrend import get_daily_trend

# set up pytrends TrendReq object
pytrend = TrendReq(hl='en-US')

keyword = 'inflation'
start = '2004-01-01'
end = '2024-01-01'
geo = 'US'
cat = 0
gprop = ''

# get_daily_trend function
overlapping = get_daily_trend(pytrend, keyword, start, end, geo=geo, cat=cat, gprop=gprop, verbose=True, tz=0)

overlapping.plot(y=keyword, figsize=(10, 6))
plt.title('Daily Google Trends for inflation')
plt.xlabel('Date')
plt.ylabel('Trend')
plt.grid(True)
plt.show()
# Out:
# Fetching 'inflation' for period:2023-04-07 2024-01-01
# Fetching 'inflation' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'inflation' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'inflation' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'inflation' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'inflation' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'inflation' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'inflation' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'inflation' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'inflation' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'inflation' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'inflation' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'inflation' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'inflation' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'inflation' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'inflation' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'inflation' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'inflation' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'inflation' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'inflation' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'inflation' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'inflation' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'inflation' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'inflation' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'inflation' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'inflation' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'inflation' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'inflation' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'inflation' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'inflation' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'inflation' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'inflation' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'inflation' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'inflation' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'inflation' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'inflation' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'inflation' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'inflation' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'inflation' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'inflation' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'inflation' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'inflation' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'inflation' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'inflation' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08

# %%
overlapping
# Out:
#             inflation  overlap
# date
# 2004-01-01        0.0      1.0
# 2004-01-02       11.0      1.0
# 2004-01-03        0.0      1.0
# 2004-01-04        0.0      1.0
# 2004-01-05        0.0      1.0
# ...               ...      ...
# 2023-12-28       16.0      NaN
# 2023-12-29       14.0      NaN
# 2023-12-30       13.0      NaN
# 2023-12-31       13.0      NaN
# 2024-01-01       13.0      NaN
#
# [7306 rows x 2 columns]

# %%
overlapping.describe()
# Out:
#          inflation  overlap
# count  7306.000000   4281.0
# mean     11.031755      1.0
# std       6.367317      0.0
# min       0.000000      1.0
# 25%       8.000000      1.0
# 50%      10.000000      1.0
# 75%      12.000000      1.0
# max     100.000000      1.0

# %% [markdown]
# # Generalized for all terms

# %% [markdown]
# ## US

# %%
start = '2004-01-01'
end = '2024-01-01'
geo = 'US'
cat = 0
gprop = ''
terms = ['inflation', 'price', 'CPI', 'cheap', 'buy', 'spend', 'save', 'donate', 'job', 'vacation', 'foreclosure', 'cash', 'credit', 'ATM']

us_terms = pd.DataFrame(index=pd.date_range(start=start, end=end))

for term in terms:
    # get_daily_trend function
    df = get_daily_trend(pytrend, term, start, end, geo=geo, cat=cat, gprop=gprop, verbose=True, tz=0)
    # rename the column to the term name
    df.rename(columns={'overlap': term}, inplace=True)
    us_terms = pd.merge(us_terms, df[term], how='left', left_index=True, right_index=True)

us_terms
# Out:
# Fetching 'inflation' for period:2023-04-07 2024-01-01
# Fetching 'inflation' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'inflation' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'inflation' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'inflation' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'inflation' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'inflation' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'inflation' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'inflation' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'inflation' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'inflation' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'inflation' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'inflation' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'inflation' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'inflation' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'inflation' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'inflation' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'inflation' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'inflation' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'inflation' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'inflation' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'inflation' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'inflation' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'inflation' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'inflation' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'inflation' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'inflation' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'inflation' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'inflation' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'inflation' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'inflation' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'inflation' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'inflation' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'inflation' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'inflation' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'inflation' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'inflation' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'inflation' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'inflation' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'inflation' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'inflation' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'inflation' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'inflation' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'inflation' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'price' for period:2023-04-07 2024-01-01
# Fetching 'price' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'price' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'price' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'price' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'price' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'price' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'price' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'price' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'price' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'price' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'price' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'price' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'price' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'price' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'price' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'price' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'price' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'price' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'price' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'price' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'price' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'price' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'price' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'price' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'price' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'price' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'price' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'price' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'price' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'price' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'price' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'price' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'price' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'price' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'price' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'price' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'price' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'price' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'price' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'price' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'price' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'price' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'price' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'CPI' for period:2023-04-07 2024-01-01
# Fetching 'CPI' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'CPI' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'CPI' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'CPI' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'CPI' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'CPI' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'CPI' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'CPI' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'CPI' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'CPI' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'CPI' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'CPI' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'CPI' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'CPI' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'CPI' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'CPI' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'CPI' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'CPI' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'CPI' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'CPI' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'CPI' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'CPI' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'CPI' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'CPI' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'CPI' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'CPI' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'CPI' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'CPI' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'CPI' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'CPI' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'CPI' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'CPI' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'CPI' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'CPI' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'CPI' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'CPI' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'CPI' for period:2006-02-22 2006-11-18
# The request failed: Google returned a response with code 429
# Trying again in 60 seconds.
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'CPI' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'CPI' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'CPI' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'CPI' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'CPI' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'CPI' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'cheap' for period:2023-04-07 2024-01-01
# Fetching 'cheap' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'cheap' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'cheap' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'cheap' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'cheap' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'cheap' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'cheap' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'cheap' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'cheap' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'cheap' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'cheap' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'cheap' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'cheap' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'cheap' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'cheap' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'cheap' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'cheap' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'cheap' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'cheap' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'cheap' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'cheap' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'cheap' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'cheap' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'cheap' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'cheap' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'cheap' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'cheap' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'cheap' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'cheap' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'cheap' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'cheap' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'cheap' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'cheap' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'cheap' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'cheap' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'cheap' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'cheap' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'cheap' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'cheap' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'cheap' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'cheap' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'cheap' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'cheap' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'buy' for period:2023-04-07 2024-01-01
# Fetching 'buy' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'buy' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'buy' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'buy' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'buy' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'buy' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'buy' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'buy' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'buy' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'buy' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'buy' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'buy' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'buy' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'buy' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'buy' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'buy' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'buy' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'buy' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'buy' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'buy' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'buy' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'buy' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'buy' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'buy' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'buy' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'buy' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'buy' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'buy' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'buy' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'buy' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'buy' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'buy' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'buy' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'buy' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'buy' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'buy' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'buy' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'buy' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'buy' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'buy' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'buy' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'buy' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'buy' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'spend' for period:2023-04-07 2024-01-01
# Fetching 'spend' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'spend' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'spend' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'spend' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'spend' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'spend' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'spend' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'spend' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'spend' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'spend' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'spend' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'spend' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'spend' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'spend' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'spend' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'spend' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'spend' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'spend' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'spend' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'spend' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'spend' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'spend' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'spend' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'spend' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'spend' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'spend' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'spend' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'spend' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'spend' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'spend' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'spend' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'spend' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'spend' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'spend' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'spend' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'spend' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'spend' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'spend' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'spend' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'spend' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'spend' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'spend' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'spend' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'save' for period:2023-04-07 2024-01-01
# Fetching 'save' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'save' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'save' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'save' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'save' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'save' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'save' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'save' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'save' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'save' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'save' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'save' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'save' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'save' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'save' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'save' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'save' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'save' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'save' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'save' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'save' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'save' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'save' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'save' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'save' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'save' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'save' for period:2010-10-09 2011-07-05
# The request failed: Google returned a response with code 429
# Trying again in 60 seconds.
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'save' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'save' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'save' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'save' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'save' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'save' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'save' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'save' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'save' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'save' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'save' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'save' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'save' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'save' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'save' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'save' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'donate' for period:2023-04-07 2024-01-01
# Fetching 'donate' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'donate' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'donate' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'donate' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'donate' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'donate' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'donate' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'donate' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'donate' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'donate' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'donate' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'donate' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'donate' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'donate' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'donate' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'donate' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'donate' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'donate' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'donate' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'donate' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'donate' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'donate' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'donate' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'donate' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'donate' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'donate' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'donate' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'donate' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'donate' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'donate' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'donate' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'donate' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'donate' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'donate' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'donate' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'donate' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'donate' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'donate' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'donate' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'donate' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'donate' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'donate' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'donate' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'job' for period:2023-04-07 2024-01-01
# Fetching 'job' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'job' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'job' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'job' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'job' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'job' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'job' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'job' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'job' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'job' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'job' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'job' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'job' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'job' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'job' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'job' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'job' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'job' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'job' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'job' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'job' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'job' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'job' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'job' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'job' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'job' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'job' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'job' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'job' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'job' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'job' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'job' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'job' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'job' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'job' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'job' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'job' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'job' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'job' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'job' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'job' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'job' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'job' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'vacation' for period:2023-04-07 2024-01-01
# Fetching 'vacation' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'vacation' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'vacation' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'vacation' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'vacation' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'vacation' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'vacation' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'vacation' for period:2019-07-25 2020-04-19
# The request failed: Google returned a response with code 429
# Trying again in 60 seconds.
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'vacation' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'vacation' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'vacation' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'vacation' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'vacation' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'vacation' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'vacation' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'vacation' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'vacation' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'vacation' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'vacation' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'vacation' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'vacation' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'vacation' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'vacation' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'vacation' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'vacation' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'vacation' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'vacation' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'vacation' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'vacation' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'vacation' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'vacation' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'vacation' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'vacation' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'vacation' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'vacation' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'vacation' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'vacation' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'vacation' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'vacation' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'vacation' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'vacation' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'vacation' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'vacation' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'foreclosure' for period:2023-04-07 2024-01-01
# Fetching 'foreclosure' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'foreclosure' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'foreclosure' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'foreclosure' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'foreclosure' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'foreclosure' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'foreclosure' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'foreclosure' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'foreclosure' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'foreclosure' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'foreclosure' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'foreclosure' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'foreclosure' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'foreclosure' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'foreclosure' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'foreclosure' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'foreclosure' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'foreclosure' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'foreclosure' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'foreclosure' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'foreclosure' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'foreclosure' for period:2013-01-31 2013-10-27
# ...
# Fetching 'cash' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'cash' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'cash' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'cash' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'cash' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'cash' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'cash' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'cash' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'cash' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'cash' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'cash' for period:2018-03-05 2018-11-29
# The request failed: Google returned a response with code 429
# Trying again in 60 seconds.
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'cash' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'cash' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'cash' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'cash' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'cash' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'cash' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'cash' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'cash' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'cash' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'cash' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'cash' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'cash' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'cash' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'cash' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'cash' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'cash' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'cash' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'cash' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'cash' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'cash' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'cash' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'cash' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'cash' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'cash' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'cash' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'cash' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'cash' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'cash' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'cash' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'cash' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'cash' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'cash' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'credit' for period:2023-04-07 2024-01-01
# Fetching 'credit' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'credit' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'credit' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'credit' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'credit' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'credit' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'credit' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'credit' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'credit' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'credit' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'credit' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'credit' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'credit' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'credit' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'credit' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'credit' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'credit' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'credit' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'credit' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'credit' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'credit' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'credit' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'credit' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'credit' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'credit' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'credit' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'credit' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'credit' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'credit' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'credit' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'credit' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'credit' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'credit' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'credit' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'credit' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'credit' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'credit' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'credit' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'credit' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'credit' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'credit' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'credit' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'credit' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'ATM' for period:2023-04-07 2024-01-01
# Fetching 'ATM' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'ATM' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'ATM' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'ATM' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'ATM' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'ATM' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'ATM' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'ATM' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'ATM' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'ATM' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'ATM' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'ATM' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'ATM' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'ATM' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'ATM' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'ATM' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'ATM' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'ATM' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'ATM' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'ATM' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'ATM' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'ATM' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'ATM' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'ATM' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'ATM' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'ATM' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'ATM' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'ATM' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'ATM' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'ATM' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'ATM' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'ATM' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'ATM' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'ATM' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'ATM' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'ATM' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'ATM' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'ATM' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'ATM' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'ATM' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'ATM' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'ATM' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'ATM' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
#             inflation  inflation  price  price  CPI  CPI  cheap  cheap   buy  \
# 2004-01-01        0.0        1.0   33.0    1.0  0.0  1.0   76.0    1.0  27.0
# 2004-01-02       11.0        1.0   29.0    1.0  0.0  1.0   66.0    1.0  24.0
# 2004-01-03        0.0        1.0   29.0    1.0  0.0  1.0   69.0    1.0  27.0
# 2004-01-04        0.0        1.0   27.0    1.0  0.0  1.0   75.0    1.0  24.0
# 2004-01-05        0.0        1.0   28.0    1.0  0.0  1.0   86.0    1.0  22.0
# ...               ...        ...    ...    ...  ...  ...    ...    ...   ...
# 2023-12-28       16.0        NaN   56.0    NaN  5.0  NaN   38.0    NaN  23.0
# 2023-12-29       14.0        NaN   52.0    NaN  5.0  NaN   37.0    NaN  24.0
# 2023-12-30       13.0        NaN   44.0    NaN  3.0  NaN   39.0    NaN  25.0
# 2023-12-31       13.0        NaN   40.0    NaN  3.0  NaN   33.0    NaN  23.0
# 2024-01-01       13.0        NaN   39.0    NaN  3.0  NaN   32.0    NaN  21.0
#
#             buy  ...  vacation  vacation  foreclosure  foreclosure  cash  \
# 2004-01-01  1.0  ...      81.0       1.0          0.0          1.0  10.0
# 2004-01-02  1.0  ...      78.0       1.0         23.0          1.0  12.0
# 2004-01-03  1.0  ...      70.0       1.0         24.0          1.0  13.0
# 2004-01-04  1.0  ...      75.0       1.0          0.0          1.0  14.0
# 2004-01-05  1.0  ...      78.0       1.0          0.0          1.0   9.0
# ...         ...  ...       ...       ...          ...          ...   ...
# 2023-12-28  NaN  ...      30.0       NaN         11.0          NaN  37.0
# 2023-12-29  NaN  ...      29.0       NaN         10.0          NaN  36.0
# 2023-12-30  NaN  ...      27.0       NaN          8.0          NaN  35.0
# 2023-12-31  NaN  ...      31.0       NaN          6.0          NaN  30.0
# 2024-01-01  NaN  ...      29.0       NaN          8.0          NaN  30.0
#
#             cash  credit  credit   ATM  ATM
# 2004-01-01   1.0    27.0     1.0   0.0  1.0
# 2004-01-02   1.0    37.0     1.0   0.0  1.0
# 2004-01-03   1.0    31.0     1.0   0.0  1.0
# 2004-01-04   1.0    26.0     1.0   0.0  1.0
# 2004-01-05   1.0    27.0     1.0   0.0  1.0
# ...          ...     ...     ...   ...  ...
# 2023-12-28   NaN    53.0     NaN  61.0  NaN
# 2023-12-29   NaN    57.0     NaN  62.0  NaN
# 2023-12-30   NaN    44.0     NaN  77.0  NaN
# 2023-12-31   NaN    33.0     NaN  56.0  NaN
# 2024-01-01   NaN    35.0     NaN  50.0  NaN
#
# [7306 rows x 28 columns]

# %%
from pytrends.request import TrendReq
import pandas as pd
from gtrend import get_daily_trend

# pytrends TrendReq object
pytrend = TrendReq(hl='en-US')

start = '2004-01-01'
end = '2024-01-01'
geo = 'US'
cat = 0
gprop = ''
terms = ['inflation', 'price', 'CPI', 'cheap', 'buy', 'spend', 'save', 'donate', 'job', 'vacation', 'foreclosure', 'cash', 'credit', 'ATM']

us_terms = pd.DataFrame(index=pd.date_range(start=start, end=end))

for term in terms:
    # get_daily_trend function
    df = get_daily_trend(pytrend, term, start, end, geo=geo, cat=cat, gprop=gprop, verbose=True, tz=0)
    df.drop(columns=['overlap'], inplace=True)
    df.rename(columns={'overlap': term}, inplace=True)
    us_terms = pd.merge(us_terms, df, how='left', left_index=True, right_index=True)

us_terms
# Out:
# Fetching 'inflation' for period:2023-04-07 2024-01-01
# Fetching 'inflation' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'inflation' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'inflation' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'inflation' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'inflation' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'inflation' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'inflation' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'inflation' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'inflation' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'inflation' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'inflation' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'inflation' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'inflation' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'inflation' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'inflation' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'inflation' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'inflation' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'inflation' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'inflation' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'inflation' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'inflation' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'inflation' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'inflation' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'inflation' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'inflation' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'inflation' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'inflation' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'inflation' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'inflation' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'inflation' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'inflation' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'inflation' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'inflation' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'inflation' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'inflation' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'inflation' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'inflation' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'inflation' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'inflation' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'inflation' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'inflation' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'inflation' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'inflation' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'price' for period:2023-04-07 2024-01-01
# Fetching 'price' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'price' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'price' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'price' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'price' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'price' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'price' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'price' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'price' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'price' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'price' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'price' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'price' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'price' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'price' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'price' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'price' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'price' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'price' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'price' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'price' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'price' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'price' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'price' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'price' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'price' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'price' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'price' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'price' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'price' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'price' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'price' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'price' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'price' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'price' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'price' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'price' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'price' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'price' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'price' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'price' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'price' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'price' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'CPI' for period:2023-04-07 2024-01-01
# Fetching 'CPI' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'CPI' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'CPI' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'CPI' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'CPI' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'CPI' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'CPI' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'CPI' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'CPI' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'CPI' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'CPI' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'CPI' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'CPI' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'CPI' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'CPI' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'CPI' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'CPI' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'CPI' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'CPI' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'CPI' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'CPI' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'CPI' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'CPI' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'CPI' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'CPI' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'CPI' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'CPI' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'CPI' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'CPI' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'CPI' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'CPI' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'CPI' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'CPI' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'CPI' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'CPI' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'CPI' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'CPI' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'CPI' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'CPI' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'CPI' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'CPI' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'CPI' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'CPI' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'cheap' for period:2023-04-07 2024-01-01
# Fetching 'cheap' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'cheap' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'cheap' for period:2021-11-16 2022-08-12
# The request failed: Google returned a response with code 429
# Trying again in 60 seconds.
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'cheap' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'cheap' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'cheap' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'cheap' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'cheap' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'cheap' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'cheap' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'cheap' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'cheap' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'cheap' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'cheap' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'cheap' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'cheap' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'cheap' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'cheap' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'cheap' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'cheap' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'cheap' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'cheap' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'cheap' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'cheap' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'cheap' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'cheap' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'cheap' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'cheap' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'cheap' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'cheap' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'cheap' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'cheap' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'cheap' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'cheap' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'cheap' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'cheap' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'cheap' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'cheap' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'cheap' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'cheap' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'cheap' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'cheap' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'cheap' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'buy' for period:2023-04-07 2024-01-01
# Fetching 'buy' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'buy' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'buy' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'buy' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'buy' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'buy' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'buy' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'buy' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'buy' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'buy' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'buy' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'buy' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'buy' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'buy' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'buy' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'buy' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'buy' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'buy' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'buy' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'buy' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'buy' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'buy' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'buy' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'buy' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'buy' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'buy' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'buy' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'buy' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'buy' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'buy' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'buy' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'buy' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'buy' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'buy' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'buy' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'buy' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'buy' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'buy' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'buy' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'buy' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'buy' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'buy' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'buy' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'spend' for period:2023-04-07 2024-01-01
# Fetching 'spend' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'spend' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'spend' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'spend' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'spend' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'spend' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'spend' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'spend' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'spend' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'spend' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'spend' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'spend' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'spend' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'spend' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'spend' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'spend' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'spend' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'spend' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'spend' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'spend' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'spend' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'spend' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'spend' for period:2012-08-15 2013-05-11
# The request failed: Google returned a response with code 429
# Trying again in 60 seconds.
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'spend' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'spend' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'spend' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'spend' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'spend' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'spend' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'spend' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'spend' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'spend' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'spend' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'spend' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'spend' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'spend' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'spend' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'spend' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'spend' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'spend' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'spend' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'spend' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'spend' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'save' for period:2023-04-07 2024-01-01
# Fetching 'save' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'save' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'save' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'save' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'save' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'save' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'save' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'save' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'save' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'save' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'save' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'save' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'save' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'save' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'save' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'save' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'save' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'save' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'save' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'save' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'save' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'save' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'save' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'save' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'save' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'save' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'save' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'save' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'save' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'save' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'save' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'save' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'save' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'save' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'save' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'save' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'save' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'save' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'save' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'save' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'save' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'save' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'save' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'donate' for period:2023-04-07 2024-01-01
# Fetching 'donate' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'donate' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'donate' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'donate' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'donate' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'donate' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'donate' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'donate' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'donate' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'donate' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'donate' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'donate' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'donate' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'donate' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'donate' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'donate' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'donate' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'donate' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'donate' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'donate' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'donate' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'donate' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'donate' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'donate' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'donate' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'donate' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'donate' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'donate' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'donate' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'donate' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'donate' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'donate' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'donate' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'donate' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'donate' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'donate' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'donate' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'donate' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'donate' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'donate' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'donate' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'donate' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'donate' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'job' for period:2023-04-07 2024-01-01
# Fetching 'job' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'job' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'job' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'job' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'job' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'job' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'job' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'job' for period:2019-07-25 2020-04-19
# The request failed: Google returned a response with code 429
# Trying again in 60 seconds.
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'job' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'job' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'job' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'job' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'job' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'job' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'job' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'job' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'job' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'job' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'job' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'job' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'job' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'job' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'job' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'job' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'job' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'job' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'job' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'job' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'job' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'job' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'job' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'job' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'job' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'job' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'job' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'job' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'job' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'job' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'job' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'job' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'job' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'job' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'job' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'vacation' for period:2023-04-07 2024-01-01
# Fetching 'vacation' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'vacation' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'vacation' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'vacation' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'vacation' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'vacation' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'vacation' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'vacation' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'vacation' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'vacation' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'vacation' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'vacation' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'vacation' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'vacation' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'vacation' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'vacation' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'vacation' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'vacation' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'vacation' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'vacation' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'vacation' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'vacation' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'vacation' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'vacation' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'vacation' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'vacation' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'vacation' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'vacation' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'vacation' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'vacation' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'vacation' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'vacation' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'vacation' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'vacation' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'vacation' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'vacation' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'vacation' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'vacation' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'vacation' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'vacation' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'vacation' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'vacation' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'vacation' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'foreclosure' for period:2023-04-07 2024-01-01
# Fetching 'foreclosure' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'foreclosure' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'foreclosure' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'foreclosure' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'foreclosure' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'foreclosure' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'foreclosure' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'foreclosure' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'foreclosure' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'foreclosure' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'foreclosure' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'foreclosure' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'foreclosure' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'foreclosure' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'foreclosure' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'foreclosure' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'foreclosure' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'foreclosure' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'foreclosure' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'foreclosure' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'foreclosure' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'foreclosure' for period:2013-01-31 2013-10-27
# ...
# Fetching 'foreclosure' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'foreclosure' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'foreclosure' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'foreclosure' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'foreclosure' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'foreclosure' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'foreclosure' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'cash' for period:2023-04-07 2024-01-01
# Fetching 'cash' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'cash' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'cash' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'cash' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'cash' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'cash' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'cash' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'cash' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'cash' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'cash' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'cash' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'cash' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'cash' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'cash' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'cash' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'cash' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'cash' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'cash' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'cash' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'cash' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'cash' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'cash' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'cash' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'cash' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'cash' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'cash' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'cash' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'cash' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'cash' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'cash' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'cash' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'cash' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'cash' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'cash' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'cash' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'cash' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'cash' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'cash' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'cash' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'cash' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'cash' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'cash' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'cash' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'credit' for period:2023-04-07 2024-01-01
# Fetching 'credit' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'credit' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'credit' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'credit' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'credit' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'credit' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'credit' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'credit' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'credit' for period:2019-02-06 2019-11-02
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'credit' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'credit' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'credit' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'credit' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'credit' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'credit' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'credit' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'credit' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'credit' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'credit' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'credit' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'credit' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'credit' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'credit' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'credit' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'credit' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'credit' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'credit' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'credit' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'credit' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'credit' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'credit' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'credit' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'credit' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'credit' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'credit' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'credit' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'credit' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'credit' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'credit' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'credit' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'credit' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'credit' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'credit' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
# Fetching 'ATM' for period:2023-04-07 2024-01-01
# Fetching 'ATM' for period:2022-10-20 2023-07-16
# Normalize by overlapping period:2023-04-07 2023-07-16
# Fetching 'ATM' for period:2022-05-04 2023-01-28
# Normalize by overlapping period:2022-10-20 2023-01-28
# Fetching 'ATM' for period:2021-11-16 2022-08-12
# Normalize by overlapping period:2022-05-04 2022-08-12
# Fetching 'ATM' for period:2021-05-31 2022-02-24
# Normalize by overlapping period:2021-11-16 2022-02-24
# Fetching 'ATM' for period:2020-12-13 2021-09-08
# Normalize by overlapping period:2021-05-31 2021-09-08
# Fetching 'ATM' for period:2020-06-27 2021-03-23
# Normalize by overlapping period:2020-12-13 2021-03-23
# Fetching 'ATM' for period:2020-01-10 2020-10-05
# Normalize by overlapping period:2020-06-27 2020-10-05
# Fetching 'ATM' for period:2019-07-25 2020-04-19
# Normalize by overlapping period:2020-01-10 2020-04-19
# Fetching 'ATM' for period:2019-02-06 2019-11-02
# The request failed: Google returned a response with code 429
# Trying again in 60 seconds.
# Normalize by overlapping period:2019-07-25 2019-11-02
# Fetching 'ATM' for period:2018-08-21 2019-05-17
# Normalize by overlapping period:2019-02-06 2019-05-17
# Fetching 'ATM' for period:2018-03-05 2018-11-29
# Normalize by overlapping period:2018-08-21 2018-11-29
# Fetching 'ATM' for period:2017-09-17 2018-06-13
# Normalize by overlapping period:2018-03-05 2018-06-13
# Fetching 'ATM' for period:2017-04-01 2017-12-26
# Normalize by overlapping period:2017-09-17 2017-12-26
# Fetching 'ATM' for period:2016-10-14 2017-07-10
# Normalize by overlapping period:2017-04-01 2017-07-10
# Fetching 'ATM' for period:2016-04-28 2017-01-22
# Normalize by overlapping period:2016-10-14 2017-01-22
# Fetching 'ATM' for period:2015-11-11 2016-08-06
# Normalize by overlapping period:2016-04-28 2016-08-06
# Fetching 'ATM' for period:2015-05-26 2016-02-19
# Normalize by overlapping period:2015-11-11 2016-02-19
# Fetching 'ATM' for period:2014-12-08 2015-09-03
# Normalize by overlapping period:2015-05-26 2015-09-03
# Fetching 'ATM' for period:2014-06-22 2015-03-18
# Normalize by overlapping period:2014-12-08 2015-03-18
# Fetching 'ATM' for period:2014-01-04 2014-09-30
# Normalize by overlapping period:2014-06-22 2014-09-30
# Fetching 'ATM' for period:2013-07-19 2014-04-14
# Normalize by overlapping period:2014-01-04 2014-04-14
# Fetching 'ATM' for period:2013-01-31 2013-10-27
# Normalize by overlapping period:2013-07-19 2013-10-27
# Fetching 'ATM' for period:2012-08-15 2013-05-11
# Normalize by overlapping period:2013-01-31 2013-05-11
# Fetching 'ATM' for period:2012-02-28 2012-11-23
# Normalize by overlapping period:2012-08-15 2012-11-23
# Fetching 'ATM' for period:2011-09-12 2012-06-07
# Normalize by overlapping period:2012-02-28 2012-06-07
# Fetching 'ATM' for period:2011-03-27 2011-12-21
# Normalize by overlapping period:2011-09-12 2011-12-21
# Fetching 'ATM' for period:2010-10-09 2011-07-05
# Normalize by overlapping period:2011-03-27 2011-07-05
# Fetching 'ATM' for period:2010-04-23 2011-01-17
# Normalize by overlapping period:2010-10-09 2011-01-17
# Fetching 'ATM' for period:2009-11-05 2010-08-01
# Normalize by overlapping period:2010-04-23 2010-08-01
# Fetching 'ATM' for period:2009-05-20 2010-02-13
# Normalize by overlapping period:2009-11-05 2010-02-13
# Fetching 'ATM' for period:2008-12-02 2009-08-28
# Normalize by overlapping period:2009-05-20 2009-08-28
# Fetching 'ATM' for period:2008-06-16 2009-03-12
# Normalize by overlapping period:2008-12-02 2009-03-12
# Fetching 'ATM' for period:2007-12-30 2008-09-24
# Normalize by overlapping period:2008-06-16 2008-09-24
# Fetching 'ATM' for period:2007-07-14 2008-04-08
# Normalize by overlapping period:2007-12-30 2008-04-08
# Fetching 'ATM' for period:2007-01-26 2007-10-22
# Normalize by overlapping period:2007-07-14 2007-10-22
# Fetching 'ATM' for period:2006-08-10 2007-05-06
# Normalize by overlapping period:2007-01-26 2007-05-06
# Fetching 'ATM' for period:2006-02-22 2006-11-18
# Normalize by overlapping period:2006-08-10 2006-11-18
# Fetching 'ATM' for period:2005-09-06 2006-06-02
# Normalize by overlapping period:2006-02-22 2006-06-02
# Fetching 'ATM' for period:2005-03-21 2005-12-15
# Normalize by overlapping period:2005-09-06 2005-12-15
# Fetching 'ATM' for period:2004-10-03 2005-06-29
# Normalize by overlapping period:2005-03-21 2005-06-29
# Fetching 'ATM' for period:2004-04-17 2005-01-11
# Normalize by overlapping period:2004-10-03 2005-01-11
# Fetching 'ATM' for period:2003-10-31 2004-07-26
# Normalize by overlapping period:2004-04-17 2004-07-26
# Fetching 'ATM' for period:2003-05-15 2004-02-08
# Normalize by overlapping period:2003-10-31 2004-02-08
#             inflation  price  CPI  cheap   buy  spend  save  donate   job  \
# 2004-01-01        0.0   33.0  0.0   76.0  27.0    0.0  18.0     0.0  18.0
# 2004-01-02       11.0   29.0  0.0   64.0  24.0    0.0  16.0    18.0  27.0
# 2004-01-03        0.0   29.0  0.0   70.0  27.0    0.0  15.0    14.0  24.0
# 2004-01-04        0.0   26.0  0.0   75.0  24.0    0.0  15.0     0.0  26.0
# 2004-01-05        0.0   28.0  0.0   90.0  22.0    0.0  18.0     0.0  29.0
# ...               ...    ...  ...    ...   ...    ...   ...     ...   ...
# 2023-12-28       16.0   56.0  5.0   37.0  24.0   64.0  29.0    29.0  18.0
# 2023-12-29       14.0   52.0  4.0   37.0  25.0   63.0  28.0    28.0  17.0
# 2023-12-30       13.0   44.0  2.0   38.0  25.0   58.0  29.0    26.0  14.0
# 2023-12-31       13.0   40.0  2.0   32.0  24.0   60.0  30.0    25.0  12.0
# 2024-01-01       13.0   39.0  2.0   31.0  21.0   61.0  30.0    22.0  13.0
#
#             vacation  foreclosure  cash  credit   ATM
# 2004-01-01      77.0          0.0  10.0    32.0   0.0
# 2004-01-02      75.0         22.0  12.0    44.0   0.0
# 2004-01-03      66.0         30.0  13.0    37.0   0.0
# 2004-01-04      72.0          0.0  14.0    32.0   0.0
# 2004-01-05      74.0          0.0   9.0    32.0   0.0
# ...              ...          ...   ...     ...   ...
# 2023-12-28      30.0         10.0  38.0    52.0  61.0
# 2023-12-29      29.0          9.0  38.0    56.0  62.0
# 2023-12-30      27.0          8.0  37.0    44.0  77.0
# 2023-12-31      31.0          6.0  31.0    32.0  56.0
# 2024-01-01      29.0          7.0  31.0    34.0  50.0
#
# [7306 rows x 14 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

us_terms.index = pd.to_datetime(us_terms.index)

plt.figure(figsize=(10, 6))
for column in us_terms.columns:
    plt.plot(us_terms.index, us_terms[column], label=column)

plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Data over Time')
plt.legend()
plt.show()

# %% [markdown]
# ## China

# %%
terms = ['通货膨胀', '价格', '消费物价指数', '便宜', '购买', '花費', '保存', '捐', '工作', '放假', '赎', '现金', '信用', '自動取款機']
chinese_terms = pd.DataFrame(index=pd.date_range(start=start, end=end))

for term in terms:
    # get_daily_trend function
    df = get_daily_trend(pytrend, term, start, end, geo=geo, cat=cat, gprop=gprop, verbose=True, tz=0)
    # rename the column to the term name
    df.rename(columns={'overlap': term}, inplace=True)
    us_terms = pd.merge(us_terms, df[term], how='left', left_index=True, right_index=True)

chinese_terms

# %%
from pytrends.request import TrendReq

pytrends = TrendReq(hl='en-US', tz=360)

kw_list = ["通货膨胀"]
pytrends.build_payload(kw_list, timeframe='2004-01-01 2024-01-01')

historical_data = pytrends.interest_over_time()
historical_data
# Out:
#             通货膨胀  isPartial
# date
# 2004-01-01    21      False
# 2004-02-01    41      False
# 2004-03-01    80      False
# 2004-04-01    83      False
# 2004-05-01    70      False
# ...          ...        ...
# 2023-09-01     4      False
# 2023-10-01     4      False
# 2023-11-01     4      False
# 2023-12-01     3      False
# 2024-01-01     4      False
#
# [241 rows x 2 columns]

# %%
from pytrends.request import TrendReq
import pandas as pd

pytrends = TrendReq(hl='en-US', tz=360)

terms = ['通货膨胀', '价格', '消费物价指数', '便宜', '购买', '花費', '保存', '捐', '工作', '放假', '赎', '现金', '信用', '自動取款機']

dfs = []

for term in terms:
    pytrends.build_payload([term], timeframe='2004-01-01 2024-01-01')

    historical_data = pytrends.interest_over_time()

    historical_data.rename(columns={'{}'.format(term): '{}'.format(term)}, inplace=True)

    dfs.append(historical_data)

china = pd.concat(dfs, axis=1)

china.drop(columns='isPartial', inplace=True)

china
# Out:
#             通货膨胀  价格  消费物价指数   便宜  购买  花費  保存   捐  工作  放假  赎  现金   信用  自動取款機
# date
# 2004-01-01    23  63       0  100  85   0  46   7  65  22  0  57   85      0
# 2004-02-01    31  89       0   65  99   0  46  11  79   2  0  93   96      0
# 2004-03-01    71  83     100   65  87   0  44   9  67   3  0  97   97      0
# 2004-04-01    81  84       0   59  88   0  47  15  66  25  0  95  100      0
# 2004-05-01    63  81       0   58  94   0  51  19  66   3  0  90   99      0
# ...          ...  ..     ...  ...  ..  ..  ..  ..  ..  .. ..  ..  ...    ...
# 2023-09-01     4   4       0   26   8  75  89   8  11   7  2   9   43      0
# 2023-10-01     4   4       0   27   8  81  91   8  10   7  3   9   41      0
# 2023-11-01     4   4       0   27   9  75  83   9  11   3  2   9   43      0
# 2023-12-01     3   4       0   27   8  74  85   9  10   6  3   9   46      0
# 2024-01-01     4   4       0   26   8  86  76   8  10   5  3   9   43      0
#
# [241 rows x 14 columns]

# %%
china.index = pd.to_datetime(china.index)

plt.figure(figsize=(10, 6))
for column in china.columns:
    plt.plot(china.index, china[column], label=column)

plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Data over Time')
plt.legend()
plt.show()
# Out:
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 36890 (\N{CJK UNIFIED IDEOGRAPH-901A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 36135 (\N{CJK UNIFIED IDEOGRAPH-8D27}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 33192 (\N{CJK UNIFIED IDEOGRAPH-81A8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 32960 (\N{CJK UNIFIED IDEOGRAPH-80C0}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20215 (\N{CJK UNIFIED IDEOGRAPH-4EF7}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26684 (\N{CJK UNIFIED IDEOGRAPH-683C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 28040 (\N{CJK UNIFIED IDEOGRAPH-6D88}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 36153 (\N{CJK UNIFIED IDEOGRAPH-8D39}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 29289 (\N{CJK UNIFIED IDEOGRAPH-7269}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25351 (\N{CJK UNIFIED IDEOGRAPH-6307}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20415 (\N{CJK UNIFIED IDEOGRAPH-4FBF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 23452 (\N{CJK UNIFIED IDEOGRAPH-5B9C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 36141 (\N{CJK UNIFIED IDEOGRAPH-8D2D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20080 (\N{CJK UNIFIED IDEOGRAPH-4E70}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 33457 (\N{CJK UNIFIED IDEOGRAPH-82B1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 36027 (\N{CJK UNIFIED IDEOGRAPH-8CBB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20445 (\N{CJK UNIFIED IDEOGRAPH-4FDD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 23384 (\N{CJK UNIFIED IDEOGRAPH-5B58}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25424 (\N{CJK UNIFIED IDEOGRAPH-6350}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24037 (\N{CJK UNIFIED IDEOGRAPH-5DE5}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20316 (\N{CJK UNIFIED IDEOGRAPH-4F5C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25918 (\N{CJK UNIFIED IDEOGRAPH-653E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20551 (\N{CJK UNIFIED IDEOGRAPH-5047}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 36174 (\N{CJK UNIFIED IDEOGRAPH-8D4E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 29616 (\N{CJK UNIFIED IDEOGRAPH-73B0}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 37329 (\N{CJK UNIFIED IDEOGRAPH-91D1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20449 (\N{CJK UNIFIED IDEOGRAPH-4FE1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 29992 (\N{CJK UNIFIED IDEOGRAPH-7528}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 33258 (\N{CJK UNIFIED IDEOGRAPH-81EA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21205 (\N{CJK UNIFIED IDEOGRAPH-52D5}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21462 (\N{CJK UNIFIED IDEOGRAPH-53D6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27454 (\N{CJK UNIFIED IDEOGRAPH-6B3E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yifanwang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27231 (\N{CJK UNIFIED IDEOGRAPH-6A5F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
